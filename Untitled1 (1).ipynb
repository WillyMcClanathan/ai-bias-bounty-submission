# %%
import pandas as pd

# Load CSVs
train = pd.read_csv("/content/loan_access_dataset.csv")
test = pd.read_csv("/content/test.csv")

# Show dimensions and sample rows
print("✅ Training shape:", train.shape)
print("✅ Test shape:", test.shape)
train.head()
# Out:
# ✅ Training shape: (10000, 16)
# ✅ Test shape: (2500, 15)
#    ID  Gender         Race  Age Age_Group  Income  Credit_Score  Loan_Amount  \
# 0   1  Female        White   74   Over 60  112117           641       378691
# 1   2  Female        White   36     25-60  155943           664       441856
# 2   3  Female        White   27     25-60  130933           550       401760
# 3   4    Male        White   67   Over 60  165816           804       159264
# 4   5    Male  Multiracial   57     25-60   81510           694       256742
#
#   Employment_Type Education_Level  Citizenship_Status Language_Proficiency  \
# 0       Full-time        Graduate             Citizen               Fluent
# 1   Self-employed     High School  Permanent Resident              Limited
# 2       Full-time        Graduate             Citizen               Fluent
# 3             Gig    Some College             Citizen               Fluent
# ...

# %% [markdown]
# ## Step 2: Preprocessing and Model Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

# Make a copy so we don't mess with original
df = train.copy()

# Convert target column to binary
df["Loan_Approved"] = df["Loan_Approved"].map({"Approved": 1, "Denied": 0})

# Encode all categorical features
encoders = {}
for col in df.select_dtypes(include='object').columns.drop("Loan_Approved"):
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

# Prepare data for training
X = df.drop(["ID", "Loan_Approved"], axis=1)
y = df["Loan_Approved"]
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, random_state=42)

# Train baseline Logistic Regression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_val)
print("✅ Accuracy:", accuracy_score(y_val, y_pred))
print("\nClassification Report:\n", classification_report(y_val, y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3-510834813.py in <cell line: 0>()
#      12 # Encode all categorical features
#      13 encoders = {}
# ---> 14 for col in df.select_dtypes(include='object').columns.drop("Loan_Approved"):
#      15     le = LabelEncoder()
#      16     df[col] = le.fit_transform(df[col])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Loan_Approved'] not found in axis"

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

# Make a copy so we don't mess with original
df = train.copy()

# Save original object columns BEFORE mapping
object_cols = df.select_dtypes(include='object').columns.tolist()

# Convert target column to binary
df["Loan_Approved"] = df["Loan_Approved"].map({"Approved": 1, "Denied": 0})

# Remove the now-numeric target from the list
object_cols.remove("Loan_Approved")

# Encode remaining categorical features
encoders = {}
for col in object_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

# Prepare features and labels
X = df.drop(["ID", "Loan_Approved"], axis=1)
y = df["Loan_Approved"]
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, random_state=42)

# Train baseline model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_val)
print("✅ Accuracy:", accuracy_score(y_val, y_pred))
print("\nClassification Report:\n", classification_report(y_val, y_pred))
# Out:
# ✅ Accuracy: 0.602
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.73      0.68      1421
#            1       0.55      0.43      0.49      1079
#
#     accuracy                           0.60      2500
#    macro avg       0.59      0.58      0.58      2500
# weighted avg       0.59      0.60      0.59      2500
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from fairlearn.reductions import ExponentiatedGradient, DemographicParity

# Create the fairness-aware mitigation model
mitigation = ExponentiatedGradient(
    LogisticRegression(max_iter=1000),
    constraints=DemographicParity()
)

# Fit it using training data and the sensitive attribute
mitigation.fit(X_train, y_train, sensitive_features=X_train["Gender"])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from fairlearn.metrics import MetricFrame, selection_rate
import matplotlib.pyplot as plt

# Predict with the fairness-mitigated model
y_pred_mitigated = mitigation.predict(X_val)

# Fairness audit for selection rate by gender
metric = MetricFrame(
    metrics=selection_rate,
    y_true=y_val,
    y_pred=y_pred_mitigated,
    sensitive_features=X_val["Gender"]
)

# Plot selection rates
metric.by_group.plot(kind='bar', title='Selection Rate by Gender')
plt.ylabel("Selection Rate")
plt.xlabel("Group")
plt.tight_layout()
plt.savefig("fairness_plot.png")
plt.show()

# %% [markdown]
# ## Step 3: Bias Audit with Fairlearn (gender)

# %%
from fairlearn.metrics import MetricFrame, selection_rate, demographic_parity_difference, equalized_odds_difference
from sklearn.metrics import accuracy_score, recall_score

# Get sensitive attribute (Gender before encoding)
sensitive_gender = train.loc[X_val.index, "Gender"]

# Compute fairness metrics
metrics = {
    "accuracy": accuracy_score,
    "recall": recall_score,
    "selection_rate": selection_rate
}

frame = MetricFrame(
    metrics=metrics,
    y_true=y_val,
    y_pred=y_pred,
    sensitive_features=sensitive_gender
)

# Bias metrics
dp_diff = demographic_parity_difference(y_val, y_pred, sensitive_features=sensitive_gender)
eo_diff = equalized_odds_difference(y_val, y_pred, sensitive_features=sensitive_gender)

# Display results
print("📊 Fairness Audit by Gender:")
display(frame.by_group)
print(f"\n🔸 Demographic Parity Difference: {dp_diff:.3f}")
print(f"🔸 Equalized Odds Difference: {eo_diff:.3f}")
# Out:
# 📊 Fairness Audit by Gender:
#             accuracy    recall  selection_rate
# Gender
# Female      0.606156  0.372659        0.286504
# Male        0.597304  0.492424        0.395956
# Non-binary  0.608696  0.588235        0.456522
# 🔸 Demographic Parity Difference: 0.170
# 🔸 Equalized Odds Difference: 0.216

# %% [markdown]
# ##PHASE 4: Bias Mitigation

# %%
from fairlearn.reductions import ExponentiatedGradient, DemographicParity
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Use the original unmitigated data
X_mit = X_train.copy()
y_mit = y_train.copy()
sensitive = train.loc[X_train.index, "Gender"]

# Define fairness constraint and mitigator
constraint = DemographicParity()
mitigator = ExponentiatedGradient(
    LogisticRegression(max_iter=1000), constraints=constraint
)

# Train fairness-aware model
mitigator.fit(X_mit, y_mit, sensitive_features=sensitive)

# Predict on validation set
y_pred_mitigated = mitigator.predict(X_val)

# Evaluate mitigated model
print("✅ Mitigated Accuracy:", accuracy_score(y_val, y_pred_mitigated))
print("\nClassification Report (Mitigated):\n", classification_report(y_val, y_pred_mitigated))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ##Fairness Audit of Mitigated Model

# %%
# Fairness audit on mitigated predictions
from fairlearn.metrics import MetricFrame, demographic_parity_difference, equalized_odds_difference, selection_rate

# Sensitive attribute
sensitive_gender = train.loc[X_val.index, "Gender"]

# Define metrics
metrics = {
    "accuracy": accuracy_score,
    "recall": recall_score,
    "selection_rate": selection_rate,
}

# Audit the mitigated model
frame_mitigated = MetricFrame(
    metrics=metrics,
    y_true=y_val,
    y_pred=y_pred_mitigated,
    sensitive_features=sensitive_gender
)

# Calculate bias metrics
dp_diff_mitigated = demographic_parity_difference(
    y_val, y_pred_mitigated, sensitive_features=sensitive_gender)
eo_diff_mitigated = equalized_odds_difference(
    y_val, y_pred_mitigated, sensitive_features=sensitive_gender)

# Show results
print("\n✅ Fairness Audit (Mitigated Model):")
display(frame_mitigated.by_group)
print(f"\n📊 Demographic Parity Difference: {dp_diff_mitigated:.3f}")
print(f"📊 Equalized Odds Difference: {eo_diff_mitigated:.3f}")
# Out:
# ✅ Fairness Audit (Mitigated Model):
#             accuracy    recall  selection_rate
# Gender
# Female      0.616417  0.423221        0.318863
# Male        0.606571  0.454545        0.352991
# Non-binary  0.586957  0.352941        0.304348
# 📊 Demographic Parity Difference: 0.049
# 📊 Equalized Odds Difference: 0.102

# %% [markdown]
# ##Model Explainability (SHAP)

# %%
import shap

# Train SHAP explainer on the training data
explainer = shap.Explainer(model.predict, X_train)
shap_values = explainer(X_val[:100])  # limit for speed

# Plot SHAP summary (feature importance)
shap.plots.beeswarm(shap_values)
# Out:
# PermutationExplainer explainer: 101it [00:11,  4.04it/s]

# %% [markdown]
# ##Final Predictions on the Test Set

# %%
# Make a copy of test set
df_test = test.copy()

# Encode test categorical features using the same encoders
for col, le in encoders.items():
    if col in df_test.columns:
        df_test[col] = le.transform(df_test[col])

# Prepare test data (drop non-numeric columns)
X_test = df_test.drop(columns=["ID"])

# Predict using the fairness-mitigated model
y_test_pred = mitigation.predict(X_test)

# Prepare submission file
submission = pd.DataFrame({
    "ID": df_test["ID"],
    "Loan_Approved": y_test_pred
})

# Map numeric predictions back to Yes/No
submission["Loan_Approved"] = submission["Loan_Approved"].map({1: "Approved", 0: "Denied"})

# Export to CSV
submission.to_csv("submission.csv", index=False)
print("✅ submission.csv created successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-1951665687.py in <cell line: 0>()
#      11
#      12 # Predict using the fairness-mitigated model
# ---> 13 y_test_pred = mitigation.predict(X_test)
#      14
#      15 # Prepare submission file
#
# NameError: name 'mitigation' is not defined

# %%
# Make a copy of test set
df_test = test.copy()

# Encode test categorical features using the same encoders
for col, le in encoders.items():
    if col in df_test.columns:
        df_test[col] = le.transform(df_test[col])

# Prepare test data (drop non-numeric columns)
X_test = df_test.drop(columns=["ID"])

# ✅ Predict using the fairness-mitigated model (fix: use `mitigator`, not `mitigation`)
y_test_pred = mitigator.predict(X_test)

# Prepare submission file
submission = pd.DataFrame({
    "ID": df_test["ID"],
    "Loan_Approved": y_test_pred
})

# Map numeric predictions back to Yes/No
submission["Loan_Approved"] = submission["Loan_Approved"].map({1: "Approved", 0: "Denied"})

# Export to CSV
submission.to_csv("submission.csv", index=False)
print("✅ submission.csv created successfully!")
# Out:
# ✅ submission.csv created successfully!

# %%
from fairlearn.metrics import MetricFrame, selection_rate
import matplotlib.pyplot as plt

# Calculate selection rate by sensitive group (e.g., sex or race)
metric = MetricFrame(metrics=selection_rate,
                     y_true=y_test,
                     y_pred=mitigated_predictions,
                     sensitive_features=X_test['Gender'])  # Change this to your actual group

# Plot
metric.by_group.plot(kind='bar', title='Selection Rate by Gender')
plt.ylabel('Selection Rate')
plt.xlabel('Group')
plt.tight_layout()
plt.savefig('fairness_plot.png')  # Save to file
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-425255028.py in <cell line: 0>()
#       4 # Calculate selection rate by sensitive group (e.g., sex or race)
#       5 metric = MetricFrame(metrics=selection_rate,
# ----> 6                      y_true=y_test,
#       7                      y_pred=mitigated_predictions,
#       8                      sensitive_features=X_test['Gender'])  # Change this to your actual group
#
# NameError: name 'y_test' is not defined
